# %%
import os
from datetime import datetime

import ipywidgets as widgets
import numpy as np
import pandas as pd
from IPython.display import HTML, display
from RiskMetrics import RiskAnalysis, create_constraint, diversification_constraint
from scipy.optimize import minimize

# %%
import numpy as np
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, FileLink
from scipy.optimize import minimize


# ==========================================================
# Helper Display
# ==========================================================

def display_scrollable_df(df, max_height="50vh", max_width="90vw"):
    style = f"""
    <div style="display:flex; justify-content:center; padding:20px;">
        <div style="
            overflow:auto;
            max-height:{max_height};
            max-width:{max_width};
            width:100%;
            border:1px solid #444;
            padding:10px;
            background-color:#000;
            color:#eee;
            font-family:'Arial Narrow', Arial, sans-serif;
            box-sizing:border-box;
        ">
            {df.to_html(border=0)}
        </div>
    </div>
    """
    return HTML(style)


# ==========================================================
# Main App
# ==========================================================

def display_app():

    # -------------------------
    # Globals
    # -------------------------
    global full_matrix, full_matrix_numpy, w0, bounds_sectors_dataframe

    full_matrix = pd.DataFrame()
    full_matrix_numpy = None
    w0 = None
    bounds_sectors_dataframe = pd.DataFrame()

    # -------------------------
    # Objective
    # -------------------------
    def objective(w):
        return np.sum((w - w0) ** 2)

    def sum_equal_one(w):
        return np.sum(w) - 1

    # -------------------------
    # Safe Constraint Builder
    # -------------------------
    def build_constraints(df_constraints):

        constraints = [{"type": "eq", "fun": sum_equal_one}]

        if df_constraints.empty:
            return constraints

        for _, row in df_constraints.iterrows():

            ticker = row["Asset"]
            sign = row["Sign"]
            limit = float(row["Limit"])

            if ticker is None:
                continue

            # -------------------------
            # Asset constraint
            # -------------------------
            if ticker in full_matrix.index:

                pos = full_matrix.index.get_loc(ticker)

                if sign == "≤":
                    constraints.append({
                        "type": "ineq",
                        "fun": lambda w, p=pos, lim=limit: lim - w[p]
                    })

                elif sign == "≥":
                    constraints.append({
                        "type": "ineq",
                        "fun": lambda w, p=pos, lim=limit: w[p] - lim
                    })

                else:
                    constraints.append({
                        "type": "eq",
                        "fun": lambda w, p=pos, lim=limit: w[p] - lim
                    })

            # -------------------------
            # Sector constraint
            # -------------------------
            elif ticker in full_matrix.columns:

                pos = full_matrix.columns.get_loc(ticker)

                if sign == "≤":
                    constraints.append({
                        "type": "ineq",
                        "fun": lambda w, p=pos, lim=limit:
                            lim - np.dot(w, full_matrix_numpy[:, p])
                    })

                elif sign == "≥":
                    constraints.append({
                        "type": "ineq",
                        "fun": lambda w, p=pos, lim=limit:
                            np.dot(w, full_matrix_numpy[:, p]) - lim
                    })

                else:
                    constraints.append({
                        "type": "eq",
                        "fun": lambda w, p=pos, lim=limit:
                            np.dot(w, full_matrix_numpy[:, p]) - lim
                    })

        return constraints


    # ==========================================================
    # Upload Handling
    # ==========================================================
    
    upload = widgets.FileUpload(accept=".xlsx", multiple=False)
    matrix_output = widgets.Output()
    upload_output = widgets.Output()
    
    def handle_upload(change):

        nonlocal optimize_btn
        global full_matrix, full_matrix_numpy, w0, bounds_sectors_dataframe

        if not upload.value:
            return

        content = upload.value[0]['content']
        file = pd.ExcelFile(pd.io.common.BytesIO(content))
        data_file = file.parse(sheet_name=file.sheet_names)

        holdings = data_file["Holdings"].set_index("Name")
        holdings = holdings.loc[holdings.index != "Cash EUR"]
        holdings["Portfolio Weighting %"] /= holdings["Portfolio Weighting %"].sum()

        sheets = file.sheet_names.copy()
        sheets.remove("Holdings")

        transparency = {}

        for sheet in sheets:
            temp = data_file[sheet].set_index("Name").iloc[:, 1:]
            temp = temp.loc[temp.index != "Cash EUR"]
            temp = temp.loc[holdings.index]
            transparency[sheet] = temp / 100

        full_matrix = pd.concat(transparency.values(), axis=1)
        full_matrix_numpy = full_matrix.to_numpy()
        w0 = holdings["Portfolio Weighting %"].loc[full_matrix.index].to_numpy()

        # Sector bounds
        bounds = {}
        for col in full_matrix.columns:
            bounds[col] = [
                full_matrix[col].min(),
                full_matrix[col].max(),
                full_matrix[col].idxmin(),
                full_matrix[col].idxmax()
            ]

        bounds_sectors_dataframe = pd.DataFrame(
            bounds,
            index=["Lower Bound", "Upper Bound", "Name Min", "Name Max"]
        ).T

        dropdown_asset.options = (
            list(full_matrix.index) +
            list(full_matrix.columns)
        )

        optimize_btn.disabled = False

        with upload_output:
            upload_output.clear_output()
            for sheet in sheets:
                temp = data_file[sheet]
                display(HTML(f'<h2>{sheet}</h2>'))

                display(temp)
            
        with matrix_output:
            matrix_output.clear_output()
            display(HTML("<h2>Transparency Matrix</h2>"))
            display(display_scrollable_df(full_matrix.round(4)))
            display(HTML("<h2>Transparency Bounds</h2>"))
            display(display_scrollable_df(bounds_sectors_dataframe.round(4)))

    upload.observe(handle_upload, names='value')

    # ==========================================================
    # Widgets
    # ==========================================================

    dropdown_asset = widgets.Dropdown(description="Constraint:", options=[])
    dropdown_sign = widgets.Dropdown(description="Sign:", options=["=", "≥", "≤"])
    dropdown_limit = widgets.FloatText(description="Limit")

    add_btn = widgets.Button(description="Add Constraint", button_style="success")
    clear_btn = widgets.Button(description="Clear All", button_style="danger")
    optimize_btn = widgets.Button(description="Optimize", button_style="primary")
    optimize_btn.disabled = True

    constraint_output = widgets.Output()
    output = widgets.Output()

    constraints_data = []

    def add_constraint(b):
        constraints_data.append({
            "Asset": dropdown_asset.value,
            "Sign": dropdown_sign.value,
            "Limit": dropdown_limit.value
        })
        with constraint_output:
            constraint_output.clear_output()
            display(pd.DataFrame(constraints_data))

    add_btn.on_click(add_constraint)

    def clear_constraints(b):
        constraints_data.clear()
        with constraint_output:
            constraint_output.clear_output()
            display(pd.DataFrame(columns=["Asset", "Sign", "Limit"]))

    clear_btn.on_click(clear_constraints)

    # ==========================================================
    # Optimization
    # ==========================================================

    def optimize(b):

        global full_matrix

        if full_matrix.empty:
            print("Upload a file first.")
            return

        df_constraints = pd.DataFrame(constraints_data)

        constraints = build_constraints(df_constraints)
        bounds = [(0, 1)] * len(w0)

        result = minimize(
            objective,
            w0,
            method="SLSQP",
            bounds=bounds,
            constraints=constraints
        )

        if not result.success:
            print("Optimization failed:", result.message)
            return

        opt_w = result.x

        initial = pd.Series(w0, index=full_matrix.index, name="Initial")
        optimal = pd.Series(opt_w, index=full_matrix.index, name="Optimised")
        res = pd.concat([initial, optimal], axis=1)
        
        res['Spread']=res['Optimised']-res['Initial']
        
        sector_alloc = pd.DataFrame(
            np.dot(res.T, full_matrix),
            index=["Initial", "Optimised",'Spread'],
            columns=full_matrix.columns
        ).T
        
            
        with output:
            output.clear_output()
            display(HTML("<h2>Results</h2>"))
            display(display_scrollable_df(res.round(4)))
            display(HTML("<h2>Sector Allocation</h2>"))
            display(display_scrollable_df(sector_alloc.round(4)))

            def get_excel(b):
                with pd.ExcelWriter("Results.xlsx", engine="openpyxl") as writer:
                    res.to_excel(writer, sheet_name="Weights")
                    sector_alloc.to_excel(writer, sheet_name="Sectors Allocation")
                    full_matrix.to_excel(writer, sheet_name="Transparency Matrix")
                    bounds_sectors_dataframe.to_excel(writer, sheet_name="Sectors Bounds")
    
            bt_excel = widgets.Button(description="Get Excel")
            bt_excel.on_click(get_excel)

            display(bt_excel)
            
    optimize_btn.on_click(optimize)

    # ==========================================================
    # Layout
    # ==========================================================

    constraint_ui = widgets.VBox([
        widgets.VBox([dropdown_asset, dropdown_sign, dropdown_limit]),
        widgets.HBox([add_btn, clear_btn, optimize_btn]),
        constraint_output
    ])
    upload_ui=widgets.VBox([upload,upload_output])
    
    tab = widgets.Tab(children=[upload_ui,
        widgets.VBox([constraint_ui, output]),
        matrix_output
    ])

    tab.set_title(0, "File Summary")
    tab.set_title(1, "Optimization")

    tab.set_title(2, "Transparency")

    display(tab)

# %%
display_app()
