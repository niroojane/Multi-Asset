# %%
import json
import os
import time
from multiprocessing import Pool, cpu_count
import datetime
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns
from ipydatagrid import DataGrid, TextRenderer
from IPython.display import HTML, display
from Add_In_Queries import *

# %%
today=datetime.date.today()

data=get_perf('PF102132','20220811',get_date_to_string(today),type_code='DecalogCodePtf')
# Out:
# /home/jovyan/notebooks/alto_studio/Risk/Analysis/Ex Post/Add_In_Queries.py:44: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["valuationDate"] = pd.to_datetime(

# %%
data['Max Nav']=data['nav'].cummax()
data['Cushion']=data['nav']/data['Max Nav']

# %%
data['Cushion'].plot()
# Out:
# <Axes: xlabel='valuationDate'>

# %%
data['Cushion'].idxmin().date(),data['Cushion'].min()
# Out:
# (datetime.date(2025, 4, 9), np.float64(0.9572987208427389))
